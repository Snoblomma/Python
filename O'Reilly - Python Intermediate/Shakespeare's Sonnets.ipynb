# %%
f = open("sonnets.txt", "r")

words = []

for line in f:
    entries = line.strip('\n\t"0123456789,.;:?!').split(" ")
    for entry in entries:
            entry = entry.strip('\n\t"0123456789,.;:?!').upper()
            if entry not in words:
                words.append(entry)
f.close()

words.sort()
len(words)
# Out:
# 3419

# %%
for word in words:
    print(word)
# Out:
# ''TIS
# 'AMEN'
# 'CIDE
# 'FAIR
# 'FORE
# 'GAINST
# 'GREEING
# 'HAD
# 'HUES'
# 'I
# 'LOVE'
# 'NO.'
# 'NOT
# 'NOW
# 'SCOPED
# 'T
# 'THIS
# 'THOU
# 'THUS
# 'TIS
# 'TRUTH
# 'TWIXT
# 'WILL'
# 'WILL,'
# 'WILL.'
# A
# A-DOTING
# ABHOR
# ABIDE
# ABLE
# ABOUT
# ABOVE
# ABSENCE
# ABSENT
# ABUNDANCE
# ABUNDANT
# ABUSE
# ABUSED
# ABUSES
# ABYSM
# ACCENTS
# ACCEPTABLE
# ACCEPTANCE
# ACCESSARY
# ACCIDENT
# ACCIDENTS
# ACCOUNT
# ACCUMULATE
# ACCUSE
# ACCUSING
# ACHIEVE
# ACKNOWLEDGE
# ACQUAINTANCE
# ACQUAINTED
# ACT
# ACTION
# ACTIVE
# ACTOR
# ADD
# ADDED
# ADDER'S
# ADDETH
# ADDING
# ADDITION
# ADIEU
# ADJUNCT
# ADMIRE
# ADMIRED
# ADMIRING
# ADMIT
# ADMITTED
# ADONIS
# ADORE
# ADULTERATE
# ADVANCE
# ADVANTAGE
# ADVERSE
# ADVISED
# ADVOCATE--
# AFAR
# AFFABLE
# AFFAIRS
# AFFECTIONS
# AFFORD
# AFFORDS
# AFLOAT
# AFRESH
# AFTER
# AFTER-LOSS
# AFTERWARDS
# AGAIN
# AGAINST
# AGE
# AGE'S
# AGES
# AGGRAVATE
# AH
# AID
# AIR
# ALACK
# ALAS
# ALCHEMY
# ALIEN
# ALIKE
# ALIVE
# ALL
# ALL-EATING
# ...
