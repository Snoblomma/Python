# %%
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
z = []

data = open("elevation_data.txt", "r").readlines()

for line in data:
    d = line.strip().split(",")
    l1 = d[0::3]
    l2 = d[1::3]
    l3 = d[2::3]
    for i in l1:
        x.append(float(i))
    for i in l2:
        y.append(float(i))
    for i in l3:
        z.append(float(i))


fig = plt.figure()
ax = Axes3D(fig)
ax.scatter3D(x, y, z, c = z, cmap=plt.cm.jet)  
ax.view_init(30, 90) ## better view

##setting size:
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

plt.show()
