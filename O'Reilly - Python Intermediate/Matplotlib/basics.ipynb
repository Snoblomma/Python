# %%
from matplotlib import pyplot

# %%
pyplot.plot([0, 2, 4, 6, 8, 10], "o-")

# %%
pyplot.ylabel("Values")
pyplot.xlabel("Time")
pyplot.title("Test plot")


# Get current size
fig_size = pyplot.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print("Current size: " + str(fig_size))
 
# Set figure width to 12 and height to 9
fig_size[0] = 6
fig_size[1] = 4
pyplot.rcParams["figure.figsize"] = fig_size

pyplot.show()
# Out:
# Current size: [6.0, 4.0]

# %%
x_values = [0, 4, 7, 12, 22, 27]
y_values = [0, 2, 4, 6, 8, 10]

# %%
pyplot.plot(x_values, y_values, "o-")

# %%
pyplot.show()

# %% [markdown]
# ### Randomly generated values

# %%
import random

y_values = [random.randint(0, 30) for elt in x_values]
pyplot.plot(x_values, y_values, "o-")
pyplot.show()

# %% [markdown]
# ### Displaying World Polpulaion

# %%
data = open("world_population.txt", "r").readlines()
dates = []
populations = []

for point in data:
    d = point.split()
    date = d[0]
    population = d[1].replace(",", "")
    dates.append(date)
    populations.append(population)
    
pyplot.plot(dates, populations, "-")
pyplot.ylabel("World population")
pyplot.xlabel("Year")
pyplot.title("World population over time")
pyplot.show()

# %% [markdown]
# ### Life expectancy

# %%
from matplotlib import pyplot as plt

data = open("life_expectancy.txt", "r").readlines()
women = []
men = []
years = []

for point in data:
    d = point.split()
    years.append(d[0])
    men.append(d[2])
    women.append(d[3])
    
plt.plot(years, women, "-", label = "Life expectancy of women")
plt.plot(years, men, "-", label = "Life expectancy of men")
plt.legend(loc='best')
plt.ylabel("Life expectancy")
plt.xlabel("Year")
plt.title("Life expactancy in US by years")

##setting size:
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

plt.show()

# %% [markdown]
# ### Deaths by Major Causes, 1960-2011

# %%
data = open("death_by_cause.txt", "r").readlines()
key = open("death_by_cause_key.txt", "r").readlines()

for i in range(0, len(key)):
    years = []
    current_key = []
    for d in data:
        sp = d.split()
        years.append(sp[0])
        current_key.append(sp[i+1])
    plt.plot(years, current_key, "-", label = key[i])
  

plt.legend(loc='best')
plt.ylabel("Cause")
plt.xlabel("Year")
plt.title("Deaths by Major Causes, 1960-2011")
plt.show()

# %% [markdown]
# ### Bar Charts

# %%
import matplotlib.pyplot as plt

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

y = [3, 10, 7, 5, 3, 4.5, 6, 8.1]
x = range(len(y))
width = 1/1.5
plt.bar(x, y, width, color="lightblue")

plt.show()

# %% [markdown]
# ### Stacked Bar Chart with Labels

# %%
import matplotlib.pyplot as plt

A = [5., 30., 45., 22.]
B = [5., 25., 50., 20.]

X = range(4)

width = 0.5

plt.bar(X, A, width = width, color = 'lightcoral')
plt.bar(X, B, width = width, color = 'lightskyblue', bottom = A)
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.2, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()
